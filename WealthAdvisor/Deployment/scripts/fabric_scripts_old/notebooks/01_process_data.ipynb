# %%
from pyspark.sql.functions import col, to_date
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, ArrayType, MapType, LongType, TimestampType, DateType
df = spark.read.format("csv").option("header","true").option("inferSchema", "true").load("Files/data/clientdata/InvestmentGoalsDetails.csv")
df = df.withColumn("ClientId", col("ClientId").cast(StringType()))

df.write.format('delta').mode('overwrite').option("overwriteSchema", "true").saveAsTable('InvestmentGoalsDetails')

# %%
from pyspark.sql.functions import col, to_date
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, ArrayType, MapType, LongType, TimestampType, DateType
df = spark.read.format("csv").option("header","true").option("inferSchema", "true").load("Files/data/clientdata/Retirement.csv")
df = df.withColumn("ClientId", col("ClientId").cast(StringType()))
df.write.format('delta').mode('overwrite').option("overwriteSchema", "true").saveAsTable('Retirement')
# display(df)

# %%
from pyspark.sql.functions import col, to_date
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, ArrayType, MapType, LongType, TimestampType, DateType
df = spark.read.format("csv").option("header","true").load("Files/data/clientdata/Clients.csv")
df = df.withColumn("ClientId", col("ClientId").cast(StringType()))
df.write.format('delta').mode('overwrite').option("overwriteSchema", "true").saveAsTable('Clients')
display(df)

# %%
from pyspark.sql.functions import col, to_date
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, ArrayType, MapType, LongType, TimestampType, DateType
df = spark.read.format("csv").option("header","true").load("Files/data/clientdata/AccountDetails.csv")
df = df.withColumn("ClientId", col("ClientId").cast(StringType()))
df.write.format('delta').mode('overwrite').option("overwriteSchema", "true").saveAsTable('AccountDetails')
display(df)

# %%
from pyspark.sql.functions import col, to_date
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, ArrayType, MapType, LongType, TimestampType, DateType
df = spark.read.format("csv").option("header","true").option("inferSchema", "true").load("Files/data/clientdata/Assets.csv")
df = df.withColumn("ClientId", col("ClientId").cast(StringType()))

df.write.format('delta').mode('overwrite').option("overwriteSchema", "true").saveAsTable('Assets')
# Out:
# StatementMeta(, 0cf7ede7-ff55-4a08-a602-c59e2f7ab591, 9, Finished, Available)

# %%
from pyspark.sql.functions import col, to_date
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, ArrayType, MapType, LongType, TimestampType, DateType
df = spark.read.format("csv").option("header","true").option("inferSchema", "true").load("Files/data/clientdata/ClientInvestmentPortfolio.csv")
df = df.withColumn("ClientId", col("ClientId").cast(StringType()))

df.write.format('delta').mode('overwrite').option("overwriteSchema", "true").saveAsTable('ClientInvestmentPortfolio')

# %%
from pyspark.sql.functions import col, to_date
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, ArrayType, MapType, LongType, TimestampType, DateType
df = spark.read.format("csv").option("header","true").option("inferSchema", "true").load("Files/data/clientdata/ClientMeetings.csv")
df = df.withColumn("ClientId", col("ClientId").cast(StringType()))

df.write.format('delta').mode('overwrite').option("overwriteSchema", "true").saveAsTable('ClientMeetings')

# %%
from pyspark.sql.functions import col, to_date
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, ArrayType, MapType, LongType, TimestampType, DateType
df = spark.read.format("csv").option("header","true").option("inferSchema", "true").load("Files/data/clientdata/InvestmentGoals.csv")
df = df.withColumn("ClientId", col("ClientId").cast(StringType()))

df.write.format('delta').mode('overwrite').option("overwriteSchema", "true").saveAsTable('InvestmentGoals')

# %%
from pyspark.sql.functions import col, to_date
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, ArrayType, MapType, LongType, TimestampType, DateType
df = spark.read.format("csv").option("header","true").option("inferSchema", "true").load("Files/data/clientdata/CalendarData.csv")
df.write.format('delta').mode('overwrite').option("overwriteSchema", "true").saveAsTable('CalendarData')
# Out:
# StatementMeta(, 4be94e2b-7267-4b6d-b23b-0549b6881981, 7, Finished, Available)
